# %% [raw]
# ---
# title: "Life Expectancy Regression Model"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     code-fold: show
#     self-contained: true
# jupyter: python3
# ---

# %% [markdown]
# Link to dataset:
# https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who?search=alcohol+effects

# %%
# import packages
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import dataset
data = pd.read_csv('Life_Expectancy_Data.csv')

# clean column names
data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# drop missing gdp values
data = data.dropna(subset=['gdp'])

data['gdp_per_capita'] = data['gdp']/data['population']

# rename HIV/AIDs column to make it usable
data = data.rename(columns={'hiv/aids': 'hiv_aids'})

# rename thinness 1-19 column to make it usable
data = data.rename(columns={'thinness__1-19_years': 'thinness_1_19_years'})

# rename thinness 5-9 column to make it usable
data = data.rename(columns={'thinness_5-9_years': 'thinness_5_9_years'})

np.random.seed(3)
train = data.sample(round(data.shape[0]*0.8)) # 80% training, 20% test
test = data.drop(train.index)
# Out:
# /var/folders/p0/ppz0yj5s4qz65pfjbd7vtldh0000gn/T/ipykernel_55049/2162178935.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
# /var/folders/p0/ppz0yj5s4qz65pfjbd7vtldh0000gn/T/ipykernel_55049/2162178935.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
data.corr()
# Out:
#                                      year  life_expectancy  adult_mortality  \
# year                             1.000000         0.162332        -0.068897
# life_expectancy                  0.162332         1.000000        -0.688458
# adult_mortality                 -0.068897        -0.688458         1.000000
# infant_deaths                   -0.037509        -0.184129         0.066432
# alcohol                         -0.049091         0.386706        -0.178217
# percentage_expenditure           0.035455         0.408237        -0.253988
# hepatitis_b                      0.089311         0.240160        -0.142424
# measles                         -0.093599        -0.147103         0.012606
# bmi                              0.097654         0.578542        -0.384456
# under-five_deaths               -0.042537        -0.209681         0.081278
# polio                            0.080652         0.458621        -0.260312
# total_expenditure                0.081448         0.183088        -0.079259
# diphtheria                       0.134202         0.470466        -0.253656
# hiv_aids                        -0.141618        -0.567730         0.536975
# gdp                              0.101620         0.461455        -0.296049
# population                       0.017359        -0.022628        -0.013180
# thinness__1-19_years            -0.050644        -0.480921         0.296772
# thinness_5-9_years              -0.054651        -0.476778         0.305205
# income_composition_of_resources  0.233216         0.735158        -0.461958
# schooling                        0.204482         0.755293        -0.450942
# gdp_per_capita                   0.008695         0.059383        -0.047054
#
#                                  infant_deaths   alcohol  \
# year                                 -0.037509 -0.049091
# life_expectancy                      -0.184129  0.386706
# adult_mortality                       0.066432 -0.178217
# infant_deaths                         1.000000 -0.105102
# alcohol                              -0.105102  1.000000
# percentage_expenditure               -0.090889  0.380379
# hepatitis_b                          -0.227924  0.069455
# measles                               0.521261 -0.031786
# bmi                                  -0.228265  0.340192
# under-five_deaths                     0.996623 -0.101209
# polio                                -0.168341  0.214230
# total_expenditure                    -0.127250  0.292360
# diphtheria                           -0.169153  0.216684
# hiv_aids                              0.015736 -0.040657
# gdp                                  -0.108427  0.354712
# population                            0.556791 -0.035582
# thinness__1-19_years                  0.483403 -0.419100
# thinness_5-9_years                    0.489793 -0.406711
# income_composition_of_resources      -0.152920  0.459385
# schooling                            -0.203257  0.558376
# gdp_per_capita                       -0.019259 -0.014493
#
#                                  percentage_expenditure  hepatitis_b  \
# year                                           0.035455     0.089311
# life_expectancy                                0.408237     0.240160
# adult_mortality                               -0.253988    -0.142424
# infant_deaths                                 -0.090889    -0.227924
# alcohol                                        0.380379     0.069455
# percentage_expenditure                         1.000000     0.021458
# hepatitis_b                                    0.021458     1.000000
# measles                                       -0.062058    -0.121469
# bmi                                            0.250049     0.147821
# under-five_deaths                             -0.093486    -0.237748
# polio                                          0.163412     0.480023
# total_expenditure                              0.207242     0.038072
# diphtheria                                     0.156624     0.617958
# hiv_aids                                      -0.111346    -0.110590
# gdp                                            0.899373     0.083903
# population                                    -0.025993    -0.123731
# thinness__1-19_years                          -0.270700    -0.110555
# thinness_5-9_years                            -0.273323    -0.120010
# income_composition_of_resources                0.395516     0.196175
# schooling                                      0.399500     0.230929
# gdp_per_capita                                 0.030592     0.037788
#
#                                   measles       bmi  under-five_deaths  ...  \
# year                            -0.093599  0.097654          -0.042537  ...
# life_expectancy                 -0.147103  0.578542          -0.209681  ...
# adult_mortality                  0.012606 -0.384456           0.081278  ...
# infant_deaths                    0.521261 -0.228265           0.996623  ...
# alcohol                         -0.031786  0.340192          -0.101209  ...
# percentage_expenditure          -0.062058  0.250049          -0.093486  ...
# hepatitis_b                     -0.121469  0.147821          -0.237748  ...
# measles                          1.000000 -0.172425           0.528549  ...
# bmi                             -0.172425  1.000000          -0.238207  ...
# under-five_deaths                0.528549 -0.238207           1.000000  ...
# polio                           -0.122371  0.284735          -0.186344  ...
# total_expenditure               -0.092809  0.200858          -0.127544  ...
# diphtheria                      -0.124742  0.282482          -0.189879  ...
# hiv_aids                         0.028484 -0.244820           0.027625  ...
# gdp                             -0.076466  0.301557          -0.112081  ...
# population                       0.265858 -0.072326           0.544432  ...
# thinness__1-19_years             0.236505 -0.531670           0.485033  ...
# thinness_5-9_years               0.232467 -0.540278           0.490275  ...
# income_composition_of_resources -0.138286  0.527781          -0.171507  ...
# schooling                       -0.146281  0.559680          -0.219288  ...
# gdp_per_capita                  -0.015423 -0.019586          -0.019762  ...
#
#                                  total_expenditure  diphtheria  hiv_aids  \
# year                                      0.081448    0.134202 -0.141618
# life_expectancy                           0.183088    0.470466 -0.567730
# adult_mortality                          -0.079259   -0.253656  0.536975
# infant_deaths                            -0.127250   -0.169153  0.015736
# alcohol                                   0.292360    0.216684 -0.040657
# percentage_expenditure                    0.207242    0.156624 -0.111346
# hepatitis_b                               0.038072    0.617958 -0.110590
# measles                                  -0.092809   -0.124742  0.028484
# bmi                                       0.200858    0.282482 -0.244820
# under-five_deaths                        -0.127544   -0.189879  0.027625
# polio                                     0.117518    0.682218 -0.160584
# total_expenditure                         1.000000    0.125440  0.024027
# diphtheria                                0.125440    1.000000 -0.167285
# hiv_aids                                  0.024027   -0.167285  1.000000
# gdp                                       0.138364    0.200666 -0.136491
# population                               -0.080358   -0.029260 -0.027816
# thinness__1-19_years                     -0.252570   -0.225247  0.203955
# thinness_5-9_years                       -0.262230   -0.222156  0.207776
# income_composition_of_resources           0.169185    0.417093 -0.256199
# schooling                                 0.245278    0.435994 -0.225954
# gdp_per_capita                            0.092811    0.031845 -0.025023
#
#                                       gdp  population  thinness__1-19_years  \
# year                             0.101620    0.017359             -0.050644
# life_expectancy                  0.461455   -0.022628             -0.480921
# adult_mortality                 -0.296049   -0.013180              0.296772
# infant_deaths                   -0.108427    0.556791              0.483403
# alcohol                          0.354712   -0.035582             -0.419100
# percentage_expenditure           0.899373   -0.025993             -0.270700
# hepatitis_b                      0.083903   -0.123731             -0.110555
# measles                         -0.076466    0.265858              0.236505
# bmi                              0.301557   -0.072326             -0.531670
# under-five_deaths               -0.112081    0.544432              0.485033
# polio                            0.211976   -0.039179             -0.217105
# total_expenditure                0.138364   -0.080358             -0.252570
# diphtheria                       0.200666   -0.029260             -0.225247
# hiv_aids                        -0.136491   -0.027816              0.203955
# gdp                              1.000000   -0.028270             -0.285697
# population                      -0.028270    1.000000              0.254224
# thinness__1-19_years            -0.285697    0.254224              1.000000
# thinness_5-9_years              -0.290539    0.251652              0.932623
# income_composition_of_resources  0.460341   -0.010379             -0.436501
# schooling                        0.448273   -0.033973             -0.474997
# gdp_per_capita                   0.026227   -0.016055              0.047004
#
#                                  thinness_5-9_years  \
# year                                      -0.054651
# life_expectancy                           -0.476778
# adult_mortality                            0.305205
# infant_deaths                              0.489793
# alcohol                                   -0.406711
# percentage_expenditure                    -0.273323
# hepatitis_b                               -0.120010
# measles                                    0.232467
# bmi                                       -0.540278
# under-five_deaths                          0.490275
# polio                                     -0.221069
# total_expenditure                         -0.262230
# diphtheria                                -0.222156
# hiv_aids                                   0.207776
# gdp                                       -0.290539
# population                                 0.251652
# thinness__1-19_years                       0.932623
# thinness_5-9_years                         1.000000
# income_composition_of_resources           -0.425081
# schooling                                 -0.464270
# gdp_per_capita                             0.046033
#
#                                  income_composition_of_resources  schooling  \
# year                                                    0.233216   0.204482
# life_expectancy                                         0.735158   0.755293
# adult_mortality                                        -0.461958  -0.450942
# infant_deaths                                          -0.152920  -0.203257
# alcohol                                                 0.459385   0.558376
# percentage_expenditure                                  0.395516   0.399500
# hepatitis_b                                             0.196175   0.230929
# measles                                                -0.138286  -0.146281
# bmi                                                     0.527781   0.559680
# under-five_deaths                                      -0.171507  -0.219288
# polio                                                   0.394748   0.430066
# total_expenditure                                       0.169185   0.245278
# diphtheria                                              0.417093   0.435994
# hiv_aids                                               -0.256199  -0.225954
# gdp                                                     0.460341   0.448273
# population                                             -0.010379  -0.033973
# thinness__1-19_years                                   -0.436501  -0.474997
# thinness_5-9_years                                     -0.425081  -0.464270
# income_composition_of_resources                         1.000000   0.804638
# schooling                                               0.804638   1.000000
# gdp_per_capita                                          0.037514   0.031230
#
#                                  gdp_per_capita
# year                                   0.008695
# life_expectancy                        0.059383
# adult_mortality                       -0.047054
# infant_deaths                         -0.019259
# alcohol                               -0.014493
# percentage_expenditure                 0.030592
# hepatitis_b                            0.037788
# measles                               -0.015423
# bmi                                   -0.019586
# under-five_deaths                     -0.019762
# polio                                  0.022445
# total_expenditure                      0.092811
# diphtheria                             0.031845
# hiv_aids                              -0.025023
# gdp                                    0.026227
# population                            -0.016055
# thinness__1-19_years                   0.047004
# thinness_5-9_years                     0.046033
# income_composition_of_resources        0.037514
# schooling                              0.031230
# gdp_per_capita                         1.000000
#
# [21 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv_aids', 'gdp', 'population', 'thinness_1_19_years',
#        'thinness_5_9_years', 'income_composition_of_resources', 'schooling',
#        'gdp_per_capita'],
#       dtype='object')

# %%
ols_object = smf.ols(formula = 'life_expectancy~schooling*income_composition_of_resources+bmi*adult_mortality*hiv_aids+np.log(gdp)+thinness_1_19_years', data=train)
model = ols_object.fit()

# returning numerical/statistical analysis
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     836.5
# Date:                Sat, 25 Feb 2023   Prob (F-statistic):               0.00
# Time:                        16:53:23   Log-Likelihood:                -5482.0
# No. Observations:                1967   AIC:                         1.099e+04
# Df Residuals:                    1954   BIC:                         1.106e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                    61.3182      0.972     63.056      0.000      59.411      63.225
# schooling                                     0.4007      0.077      5.227      0.000       0.250       0.551
# income_composition_of_resources              -0.8849      1.448     -0.611      0.541      -3.726       1.956
# schooling:income_composition_of_resources     0.7559      0.112      6.749      0.000       0.536       0.976
# bmi                                          -0.0052      0.009     -0.565      0.572      -0.023       0.013
# adult_mortality                              -0.0298      0.002    -14.798      0.000      -0.034      -0.026
# bmi:adult_mortality                           0.0001   5.63e-05      2.436      0.015    2.67e-05       0.000
# hiv_aids                                     -1.9114      0.124    -15.420      0.000      -2.155      -1.668
# bmi:hiv_aids                                  0.0434      0.005      9.300      0.000       0.034       0.053
# adult_mortality:hiv_aids                      0.0030      0.000     11.253      0.000       0.003       0.004
# bmi:adult_mortality:hiv_aids              -8.267e-05    9.9e-06     -8.347      0.000      -0.000   -6.32e-05
# np.log(gdp)                                   0.4439      0.064      6.915      0.000       0.318       0.570
# thinness_1_19_years                          -0.1022      0.024     -4.181      0.000      -0.150      -0.054
# ==============================================================================
# Omnibus:                      160.477   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              554.688
# Skew:                          -0.362   Prob(JB):                    3.56e-121
# Kurtosis:                       5.499   Cond. No.                     1.38e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Computing RMSE on test data
pred_life = model.predict(test)
np.sqrt(((test.life_expectancy - pred_life)**2).mean())
# Out:
# 3.4732131033924056
